# %%
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
import seaborn as sns

# %%
df = pd.read_csv("IndiaCovid.csv")

# %%
df.head()
# Out:
#          Date Country  Tests  Day+   Day-
# 0  05-04-2020   India   9369   295   9074
# 1  06-04-2020   India  11432   311  11121
# 2  07-04-2020   India  12584   285  12299
# 3  08-04-2020   India  13413   320  13093
# 4  09-04-2020   India  16002   320  15682

# %%
plt.plot(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-fbcb7f9f3ed2> in <module>
# ----> 1 plt.plot(df)
#
# ~\Anaconda3\envs\gputest\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~\Anaconda3\envs\gputest\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ...

# %%
df.set_index('Date').plot(figsize=(10,5), grid=True)

# %%
ax = sns.lineplot(x="Day+", y="Tests", data=df)

# %%
ax = sns.lineplot(x="Day-", y="Tests", data=df)

# %%
df2 = pd.read_csv("USACovid.csv")

# %%
df2.head()
# Out:
#          Date Country   Tests   Day+    Day-
# 0  05-04-2020      US  151200  28799  122401
# 1  06-04-2020      US  152905  30483  122422
# 2  07-04-2020      US  144231  30000  114231
# 3  08-04-2020      US  165886  34325  131561
# 4  09-04-2020      US  157988  34422  123566

# %%
df2.set_index('Date').plot(figsize=(10,5), grid=True)

# %%
ax = sns.lineplot(x="Day+", y="Tests", data=df2)

# %%
ax = sns.lineplot(x="Day-", y="Tests", data=df2)

# %%
from sklearn import linear_model
from sklearn import preprocessing, svm 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression

# %%
import numpy as np

# %% [markdown]
# # India

# %%
X = np.array(df['Tests']).reshape(-1, 1) 
y = np.array(df['Day+']).reshape(-1, 1)

# %%
# Dropping any rows with Nan values 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25) 
  
# Splitting the data into training and testing data 
regr = LinearRegression() 
  
regr.fit(X_train, y_train) 
print(regr.score(X_test, y_test))
# Out:
# 0.9366463396703293

# %%
y_pred = regr.predict(X_test) 
plt.scatter(X_test, y_test, color ='b') 
plt.plot(X_test, y_pred, color ='k') 
  
plt.show() 
# Data scatter of predicted values

# %%
X1 = np.array(df['Tests']).reshape(-1, 1) 
y1 = np.array(df['Day-']).reshape(-1, 1) 

# Dropping any rows with Nan values 
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size = 0.25) 
  
# Splitting the data into training and testing data 
regr1 = LinearRegression() 
  
regr1.fit(X_train1, y_train1) 
print(regr.score(X_test1, y_test1))
# Out:
# -1.449184353542225

# %%
y_pred1 = regr.predict(X_test1) 
plt.scatter(X_test1, y_test1, color ='b') 
plt.plot(X_test1, y_pred1, color ='k') 
  
plt.show() 
# Data scatter of predicted values

# %%
df.describe()
# Out:
#                Tests         Day+           Day-
# count      53.000000    53.000000      53.000000
# mean    59182.264151  2885.207547   56297.056604
# std     33998.765349  2063.533511   32080.417827
# min      9369.000000   285.000000    9074.000000
# 25%     26351.000000  1243.000000   25406.000000
# 50%     60783.000000  2396.000000   57636.000000
# 75%     90170.000000  3991.000000   83756.000000
# max    116041.000000  7271.000000  108770.000000

# %% [markdown]
# # USA

# %%
X2 = np.array(df2['Tests']).reshape(-1, 1) 
y2 = np.array(df2['Day+']).reshape(-1, 1) 


# Dropping any rows with Nan values 
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size = 0.25) 
  
# Splitting the data into training and testing data 
regr2 = LinearRegression() 
  
regr2.fit(X_train2, y_train2) 
print(regr.score(X_test2, y_test2))
# Out:
# -6.856162088957989

# %%
X3 = np.array(df2['Tests']).reshape(-1, 1) 
y3 = np.array(df2['Day-']).reshape(-1, 1) 


# Dropping any rows with Nan values 
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, test_size = 0.25) 
  
# Splitting the data into training and testing data 
regr3 = LinearRegression() 
  
regr3.fit(X_train3, y_train3) 
print(regr.score(X_test3, y_test3))
# Out:
# -4.510841921884649

# %%
y_pred1 = regr.predict(X_test1) 
plt.scatter(X_test1, y_test1, color ='b') 
plt.plot(X_test1, y_pred1, color ='k') 
  
plt.show() 
# Data scatter of predicted values
